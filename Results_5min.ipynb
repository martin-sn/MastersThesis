# %%
from deep_models import *

# %% [markdown]
# # 5 Min Data - 5 Min Forecast #

# %%
Y = pd.read_csv("data/final/5min/BTC_Y_std.csv")

# %% [markdown]
# ## Dense Models ##

# %% [markdown]
# #### Bid Ask Features ####

# %%
data_std = pd.read_csv("data/final/5min/BidAsk/BTC_std.csv")

# %%
data_std.shape
# Out:
# (3350, 33)

# %%
3350/12
# Out:
# 279.1666666666667

# %%
3350-280
# Out:
# 3070

# %%
3350-280*2
# Out:
# 2790

# %%
test, Y_test, His1, His2, His3, Mod1, Mod2, Mod3 = Run_Dense(data_std, Y, "test", 2790, 3070)

# %% [markdown]
# #### Model 1 #####

# %%
plt.plot(His1.history['loss'])
plt.plot(His1.history['val_loss'])

# %%
Eval(Mod1, test, Y_test)
# Out:
# Accuray = 0.3054545454545455, ROC = 0.5035862158084734

# %% [markdown]
# #### Model 2 ####

# %%
plt.plot(His2.history['loss'])
plt.plot(His2.history['val_loss'])

# %%
Eval(Mod2, test, Y_test)
# Out:
# Accuray = 0.36727272727272725, ROC = 0.5450910272306201

# %% [markdown]
# #### Model 3 ####

# %%
plt.plot(His3.history['loss'])
plt.plot(His3.history['val_loss'])

# %%
Eval(Mod3, test, Y_test)
# Out:
# Accuray = 0.3927272727272727, ROC = 0.5574014628944218

# %% [markdown]
# ### Order flow features ###

# %%
data_std = pd.read_csv("data/final/5min/OrderFlow/BTC_std.csv")

# %%
test, Y_test, His1, His2, His3, Mod1, Mod2, Mod3 = Run_Dense(data_std, Y, "test", 2790, 3070)

# %% [markdown]
# #### Model 1 ####

# %%
plt.plot(His1.history['loss'])
plt.plot(His1.history['val_loss'])

# %%
Eval(Mod1, test, Y_test)
# Out:
# Accuray = 0.4, ROC = 0.557773044331401

# %% [markdown]
# #### Model 2 ####

# %%
plt.plot(His2.history['loss'])
plt.plot(His2.history['val_loss'])

# %%
Eval(Mod2, test, Y_test)
# Out:
# Accuray = 0.33454545454545453, ROC = 0.5054739792049961

# %% [markdown]
# #### Model 3 ####

# %%
plt.plot(His3.history['loss'])
plt.plot(His3.history['val_loss'])

# %%
Eval(Mod3, test, Y_test)
# Out:
# Accuray = 0.3490909090909091, ROC = 0.4943703927227081

# %% [markdown]
# ### High Frequency Features ###

# %%
data_std = pd.read_csv("data/final/5min/HF/BTC_std.csv")

# %%
test, Y_test, His1, His2, His3, Mod1, Mod2, Mod3 = Run_Dense(data_std, Y, "test", 2790, 3070)

# %% [markdown]
# #### Model 1 ####

# %%
plt.plot(His1.history['loss'])
plt.plot(His1.history['val_loss'])

# %%
Eval(Mod1, test, Y_test)
# Out:
# Accuray = 0.3490909090909091, ROC = 0.5494719617358802

# %% [markdown]
# #### Model 2 ####

# %%
plt.plot(His2.history['loss'])
plt.plot(His2.history['val_loss'])

# %%
Eval(Mod2, test, Y_test)
# Out:
# Accuray = 0.37454545454545457, ROC = 0.558960588789106

# %% [markdown]
# #### Model 3 ####

# %%
plt.plot(His3.history['loss'])
plt.plot(His3.history['val_loss'])

# %%
Eval(Mod3, test, Y_test)
# Out:
# Accuray = 0.3527272727272727, ROC = 0.5141099080613113

# %% [markdown]
# ### LSTM Models ###

# %% [markdown]
# #### Bid Ask Features ####

# %%
data_std = pd.read_csv("data/final/5min/BidAsk/BTC_std.csv")

# %%
test_lstm, Y_test_lstm, His1, Mod1 = Run_LSTM(data_std, Y, "test", 2790, 3070)

# %% [markdown]
# #### Model 1 #####

# %%
plt.plot(His1.history['loss'])
plt.plot(His1.history['val_loss'])

# %%
Eval_LSTM(Mod1, test_lstm, Y_test_lstm, 3070)
# Out:
# Accuray = 0.33214285714285713, ROC = 0.49130219229821465

# %% [markdown]
# #### Order Flow Features ####

# %%
data_std = pd.read_csv("data/final/5min/OrderFlow/BTC_std.csv")

# %%
test_lstm, Y_test_lstm, His1, Mod1 = Run_LSTM(data_std, Y, "test", 2790, 3070)

# %% [markdown]
# #### Model 1 #####

# %%
plt.plot(His1.history['loss'])
plt.plot(His1.history['val_loss'])

# %%
Eval_LSTM(Mod1, test_lstm, Y_test_lstm, 3070)
# Out:
# Accuray = 0.3678571428571429, ROC = 0.5561647676883515

# %% [markdown]
# #### High Frequency Features ####

# %%
data_std = pd.read_csv("data/final/5min/HF/BTC_std.csv")

# %%
test_lstm, Y_test_lstm, His1, Mod1 = Run_LSTM(data_std, Y, "test",2790, 3070)

# %% [markdown]
# #### Model 1 #####

# %%
plt.plot(His1.history['loss'])
plt.plot(His1.history['val_loss'])

# %%
Eval_LSTM(Mod1, test_lstm, Y_test_lstm, 3070)
# Out:
# Accuray = 0.375, ROC = 0.5526084738447169
