# %%
from deep_models import *

# %% [markdown]
# # 1 Min Data - 1 Min Forecast #

# %%
Y = pd.read_csv("data/final/1min/BTC_Y_std.csv")

# %% [markdown]
# ## Dense Models ##

# %% [markdown]
# #### Bid Ask Features ####

# %%
data_std = pd.read_csv("data/final/1min/BidAsk/BTC_std.csv")

# %%
test, Y_test, His1, His2, His3, Mod1, Mod2, Mod3 = Run_Dense(data_std, Y, "test")

# %% [markdown]
# #### Model 1 #####

# %%
plt.plot(His1.history['loss'])
plt.plot(His1.history['val_loss'])

# %%
Eval(Mod1, test, Y_test)
# Out:
# Accuray = 0.3473752430330525, ROC = 0.5412872469949808

# %% [markdown]
# #### Model 2 ####

# %%
plt.plot(His2.history['loss'])
plt.plot(His2.history['val_loss'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-4d97876043c7> in <module>
# ----> 1 plt.plot(His2.history['loss'])
#       2 plt.plot(His2.history['val_loss'])
#
# NameError: name 'His2' is not defined

# %%
Eval(Mod2, test, Y_test)
# Out:
# Accuray = 0.3590408295528192, ROC = 0.5509522773794436

# %% [markdown]
# #### Model 3 ####

# %%
plt.plot(His3.history['loss'])
plt.plot(His3.history['val_loss'])

# %%
Eval(Mod3, test, Y_test)
# Out:
# Accuray = 0.3771872974724563, ROC = 0.5265843993161511

# %% [markdown]
# ### Order flow features ###

# %%
data_std = pd.read_csv("data/final/1min/OrderFlow/BTC_std.csv")

# %%
test, Y_test, His1, His2, His3, Mod1, Mod2, Mod3 = Run_Dense(data_std, Y, "test")

# %% [markdown]
# #### Model 1 ####

# %%
plt.plot(His1.history['loss'])
plt.plot(His1.history['val_loss'])

# %%
Eval(Mod1, test, Y_test)
# Out:
# Accuray = 0.3849643551523007, ROC = 0.5398722592235781

# %% [markdown]
# #### Model 2 ####

# %%
plt.plot(His2.history['loss'])
plt.plot(His2.history['val_loss'])

# %%
Eval(Mod2, test, Y_test)
# Out:
# Accuray = 0.37005832793259885, ROC = 0.5344642607652721

# %% [markdown]
# #### Model 3 ####

# %%
plt.plot(His3.history['loss'])
plt.plot(His3.history['val_loss'])

# %%
Eval(Mod3, test, Y_test)
# Out:
# Accuray = 0.3674659753726507, ROC = 0.5393401167995552

# %% [markdown]
# ### High Frequency Features ###

# %%
data_std = pd.read_csv("data/final/1min/HF/BTC_std.csv")

# %%
test, Y_test, His1, His2, His3, Mod1, Mod2, Mod3 = Run_Dense(data_std, Y, "test")

# %% [markdown]
# #### Model 1 ####

# %%
plt.plot(His1.history['loss'])
plt.plot(His1.history['val_loss'])

# %%
Eval(Mod1, test, Y_test)
# Out:
# Accuray = 0.3421905379131562, ROC = 0.547488383252544

# %% [markdown]
# #### Model 2 ####

# %%
plt.plot(His2.history['loss'])
plt.plot(His2.history['val_loss'])

# %%
Eval(Mod2, test, Y_test)
# Out:
# Accuray = 0.33506156837329876, ROC = 0.5181544444248076

# %% [markdown]
# #### Model 3 ####

# %%
plt.plot(His3.history['loss'])
plt.plot(His3.history['val_loss'])

# %%
Eval(Mod3, test, Y_test)
# Out:
# Accuray = 0.36228127025275436, ROC = 0.5177284655582672

# %% [markdown]
# ### LSTM Models ###

# %% [markdown]
# #### Bid Ask Features ####

# %%
data_std = pd.read_csv("data/final/1min/BidAsk/BTC_std.csv")

# %%
test_lstm, Y_test_lstm, His1, Mod1 = Run_LSTM(data_std, Y, "test")

# %% [markdown]
# #### Model 1 #####

# %%
plt.plot(His1.history['loss'])
plt.plot(His1.history['val_loss'])

# %%
Eval_LSTM(Mod1, test_lstm, Y_test_lstm)
# Out:
# Accuray = 0.3494832041343669, ROC = 0.5011338184765279

# %% [markdown]
# #### Order Flow Features ####

# %%
data_std = pd.read_csv("data/final/1min/OrderFlow/BTC_std.csv")

# %%
test_lstm, Y_test_lstm, His1, Mod1 = Run_LSTM(data_std, Y, "test")

# %% [markdown]
# #### Model 1 #####

# %%
plt.plot(His1.history['loss'])
plt.plot(His1.history['val_loss'])

# %%
Eval_LSTM(Mod1, test_lstm, Y_test_lstm)
# Out:
# Accuray = 0.38372093023255816, ROC = 0.5640987305201869

# %% [markdown]
# #### High Frequency Features ####

# %%
data_std = pd.read_csv("data/final/1min/HF/BTC_std.csv")

# %%
test_lstm, Y_test_lstm, His1, Mod1 = Run_LSTM(data_std, Y, "test")

# %% [markdown]
# #### Model 1 #####

# %%
plt.plot(His1.history['loss'])
plt.plot(His1.history['val_loss'])

# %%
Eval_LSTM(Mod1, test_lstm, Y_test_lstm)
# Out:
# Accuray = 0.3785529715762274, ROC = 0.5590407507595611
