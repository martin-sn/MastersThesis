# %%
from deep_models import *

# %% [markdown]
# # 1 Min Data - 5 Min Forecast #

# %%
Y = pd.read_csv("data/final/1min/BTC_Y_5_std.csv")

# %% [markdown]
# ## Dense Models ##

# %% [markdown]
# #### Bid Ask Features ####

# %%
data_std = pd.read_csv("data/final/1min/BidAsk/BTC_std_5.csv")

# %%
test, Y_test, His1, His2, His3, Mod1, Mod2, Mod3 = Run_Dense(data_std, Y, "test")

# %% [markdown]
# #### Model 1 #####

# %%
plt.plot(His1.history['loss'])
plt.plot(His1.history['val_loss'])

# %%
Eval(Mod1, test, Y_test)
# Out:
# Accuray = 0.42105263157894735, ROC = 0.5274609883936137

# %% [markdown]
# #### Model 2 ####

# %%
plt.plot(His2.history['loss'])
plt.plot(His2.history['val_loss'])

# %%
Eval(Mod2, test, Y_test)
# Out:
# Accuray = 0.41455490578297594, ROC = 0.5284314435897292

# %% [markdown]
# #### Model 3 ####

# %%
plt.plot(His3.history['loss'])
plt.plot(His3.history['val_loss'])

# %%
Eval(Mod3, test, Y_test)
# Out:
# Accuray = 0.32618583495776476, ROC = 0.5045507157637251

# %% [markdown]
# ### Order flow features ###

# %%
data_std = pd.read_csv("data/final/1min/OrderFlow/BTC_std_5.csv")

# %%
test, Y_test, His1, His2, His3, Mod1, Mod2, Mod3 = Run_Dense(data_std, Y, "test")

# %% [markdown]
# #### Model 1 ####

# %%
plt.plot(His1.history['loss'])
plt.plot(His1.history['val_loss'])

# %%
Eval(Mod1, test, Y_test)
# Out:
# Accuray = 0.437946718648473, ROC = 0.5322064269476693

# %% [markdown]
# #### Model 2 ####

# %%
plt.plot(His2.history['loss'])
plt.plot(His2.history['val_loss'])

# %%
Eval(Mod2, test, Y_test)
# Out:
# Accuray = 0.3820662768031189, ROC = 0.4951259822938808

# %% [markdown]
# #### Model 3 ####

# %%
plt.plot(His3.history['loss'])
plt.plot(His3.history['val_loss'])

# %%
Eval(Mod3, test, Y_test)
# Out:
# Accuray = 0.3476283300844704, ROC = 0.5057568992439672

# %% [markdown]
# ### High Frequency Features ###

# %%
data_std = pd.read_csv("data/final/1min/HF/BTC_std_5.csv")

# %%
test, Y_test, His1, His2, His3, Mod1, Mod2, Mod3 = Run_Dense(data_std, Y, "test")

# %% [markdown]
# #### Model 1 ####

# %%
plt.plot(His1.history['loss'])
plt.plot(His1.history['val_loss'])

# %%
Eval(Mod1, test, Y_test)
# Out:
# Accuray = 0.4061078622482131, ROC = 0.5310310122947509

# %% [markdown]
# #### Model 2 ####

# %%
plt.plot(His2.history['loss'])
plt.plot(His2.history['val_loss'])

# %%
Eval(Mod2, test, Y_test)
# Out:
# Accuray = 0.3788174139051332, ROC = 0.5069494051118033

# %% [markdown]
# #### Model 3 ####

# %%
plt.plot(His3.history['loss'])
plt.plot(His3.history['val_loss'])

# %%
Eval(Mod3, test, Y_test)
# Out:
# Accuray = 0.4015594541910331, ROC = 0.5084889149597621

# %% [markdown]
# ### LSTM Models ###

# %% [markdown]
# #### Bid Ask Features ####

# %%
data_std = pd.read_csv("data/final/1min/BidAsk/BTC_std_5.csv")

# %%
test_lstm, Y_test_lstm, His1, Mod1 = Run_LSTM(data_std, Y, "test")

# %% [markdown]
# #### Model 1 #####

# %%
plt.plot(His1.history['loss'])
plt.plot(His1.history['val_loss'])

# %%
Eval_LSTM(Mod1, test_lstm, Y_test_lstm)
# Out:
# Accuray = 0.41386010362694303, ROC = 0.5414860321979408

# %% [markdown]
# #### Order Flow Features ####

# %%
data_std = pd.read_csv("data/final/1min/OrderFlow/BTC_std_5.csv")

# %%
test_lstm, Y_test_lstm, His1, Mod1 = Run_LSTM(data_std, Y, "test")

# %% [markdown]
# #### Model 1 #####

# %%
plt.plot(His1.history['loss'])
plt.plot(His1.history['val_loss'])

# %%
Eval_LSTM(Mod1, test_lstm, Y_test_lstm)
# Out:
# Accuray = 0.4106217616580311, ROC = 0.5228118560043137

# %% [markdown]
# #### High Frequency Features ####

# %%
data_std = pd.read_csv("data/final/1min/HF/BTC_std_5.csv")

# %%
test_lstm, Y_test_lstm, His1, Mod1 = Run_LSTM(data_std, Y, "test")

# %% [markdown]
# #### Model 1 #####

# %%
plt.plot(His1.history['loss'])
plt.plot(His1.history['val_loss'])

# %%
Eval_LSTM(Mod1, test_lstm, Y_test_lstm)
# Out:
# Accuray = 0.4410621761658031, ROC = 0.5490037456770126
